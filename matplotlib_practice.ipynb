# %%
import matplotlib
matplotlib.__version__

# %matplotlib inline

import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis)

# %%
fig,ax = plt.subplots()
ax.plot(x_axis,y_axis)

# %%
fig = plt.figure()
ax = fit.add_subplot()
ax.plot(x_axis,y_axis)
# Out:
# <ipython-input-51-99f81a198cc2>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fit.add_subplot()

# %%
plt.figure()
plt.plot(x_axis,y_axis,label ="Boston",color = "purple",linewidth = 3, marker ="*")
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("this is the plot i am thinking of")
plt.legend()
plt.grid()

# %%
fig,ax = plt.subplots(figsize = (10,5))
ax.plot(x_axis,y_axis,label ='Boston',linewidth= 2,color = "green",marker ="D")
ax.set_ylim([0,30])
ax.set_xlabel('how much ($)')
ax.set_title("all those are experiment")
ax.grid()
ax.legend()

# %%
plt.bar(x_axis,y_axis,label ="Boston",color ="green")
plt.xlabel('Date')
plt.ylabel('Fare($)')
plt.legend()

# %%
plt.barh(x_axis,y_axis,label = "Boston",color = "magenta")
plt.xlabel('Fare ($)')
plt.ylabel("Date")
plt.legend()
plt.gca().invert_yaxis()

# %%
plt.barh(x_axis,y_axis,label = "Chicago",color = "cyan")
plt.xlabel('Fare ($)')
plt.ylabel("Date")
plt.legend()
plt.gca().invert_yaxis()

# %%
#scater plot
plt.plot(y_axis,x_axis,"o",color = "red",label ="Chicago")
plt.xlabel('Date')
plt.ylabel('Fare($)')
plt.xlim([0,50])
plt.legend()
plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis,y_axis,s=y_axis)

# %%
y_axis_larger = []
for d in y_axis:
    y_axis_larger.append(d*4)
plt.scatter(x_axis,y_axis,s=y_axis_larger)

# %%
plt.scatter(x_axis,y_axis,s =[i * 5 for i in y_axis])

# %%
fig,ax = plt.subplots()
ax.scatter(y_axis,x_axis,s =[i * 5 for i in y_axis]
           ,color = "skyblue",label ="Boston",edgecolor ="k",
          alpha = 0.8)
ax.set_title('PyBer Fare by Month')
ax.set_ylabel('Date')
ax.set_xlabel('Fare($)')
ax.set_xlim([0,50])
ax.legend()
ax.invert_yaxis()

# %%
plt.pie(y_axis,labels=x_axis)
# Out:
# ([<matplotlib.patches.Wedge at 0x2aa73fbdbb0>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.7729302540020312, -0.782674148319948, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')])

# %%
import statistics

# %%
std = statistics.stdev(y_axis)
std
# Out:
# 11.208367917035753

# %%
fig,ax = plt.subplots()
ax.errorbar(x_axis,y_axis,yerr = std,capsize = 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x_axis,y_axis, yerr = std,capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis,y_axis,yerr = std,capsize = 6)
# Out:
# <BarContainer object of 12 artists>

# %%
from matplotlib.ticker import MultipleLocator
ticks = np.arange(0,51,step =5)

plt.barh(x_axis,y_axis,xerr = std,capsize = 5)
plt.xticks(ticks)
plt.gca().invert_yaxis()
plt.gca().xaxis.set_minor_locator(MultipleLocator(1))
ticks
# Out:
# array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
from matplotlib.ticker import MultipleLocator
fig,ax = plt.subplots()
ax.barh(x_axis,y_axis,xerr = std,capsize = 4)
ax.invert_yaxis()
ticks = np.arange(0,51,step = 5)
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xticks(ticks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-252-018db0d321c3> in <module>
#       5 ticks = np.arange(0,51,step = 5)
#       6 ax.xaxis.set_minor_locator(MultipleLocator(1))
# ----> 7 ax.xticks(ticks)
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
import csv
import pandas as pd
city_to_read = "Resources/city_data.csv"
ride_to_read = "Resources/ride_data.csv"

# %%
city_df = pd.read_csv(city_to_read)
ride_df = pd.read_csv(ride_to_read)
sum(city_df['type'] == "Rural")
print(city_df.head())
ride_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344

# %%
ride_city_df = pd.merge(ride_df,city_df,how = "inner",on =['city','city'])
ride_city_df.head(15)
# Out:
#                   city                 date   fare        ride_id  \
# 0   Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1   Lake Jonathanshire  2019-04-07 20:51:11  31.25  4441251834598
# 2   Lake Jonathanshire  2019-03-09 23:45:55  19.89  2389495660448
# 3   Lake Jonathanshire  2019-04-07 18:09:21  24.28  7796805191168
# 4   Lake Jonathanshire  2019-01-02 14:14:50  13.89   424254840012
# 5   Lake Jonathanshire  2019-04-06 11:30:32  16.84  6164453571846
# 6   Lake Jonathanshire  2019-03-21 00:18:34  37.95  8353656732934
# 7   Lake Jonathanshire  2019-01-28 00:07:00   5.67  9756573174778
# 8   Lake Jonathanshire  2019-01-24 12:24:22  34.65  3319117904437
# 9   Lake Jonathanshire  2019-03-24 16:27:49  14.94  1670908453476
# 10  Lake Jonathanshire  2019-04-11 22:10:30  12.81  5999870428814
# 11  Lake Jonathanshire  2019-01-23 21:43:16  21.11  7711472105447
# 12  Lake Jonathanshire  2019-01-29 00:19:07  41.05  6649692036139
# ...
